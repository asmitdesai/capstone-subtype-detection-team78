# %% [markdown]
# # Fine-Tuning the CNN on Cancer and Subtype

# %%
# !pip install tf_keras
# Out:
# Collecting tf_keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tf_keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.4.0)
# Requirement already satisfied: packaging in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.32.5)
# Requirement already satisfied: setuptools in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (82.0.0)
# Requirement already satisfied: six>=1.12.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.4.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf_keras) (0.46.3)
# Requirement already satisfied: rich in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (14.3.2)
# Requirement already satisfied: namex in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.0)
# Requirement already satisfied: optree in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.10.2)
# Requirement already satisfied: pillow in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.2)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.0 MB/s eta 0:00:0031m10.2 MB/s eta 0:00:01
# Installing collected packages: tf_keras
# Successfully installed tf_keras-2.20.1

# %%
import os
import sys
from pathlib import Path

# --- CRITICAL CONFIG ---
# This forces TensorFlow to use the legacy Keras 2 behavior
# which supports your older folder-based models.
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# Prevent log clutter
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

import pandas as pd
import numpy as np
import tensorflow as tf

# Check that the legacy import works
import tf_keras as keras 

# Setup paths
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from config import THYROID_PATH, MODEL_PATH, RESULTS_PATH

print(f"✅ Environment Ready. TensorFlow version: {tf.__version__}")
print(f"✅ Keras version: {keras.__version__}") # Should say 2.15.x or similar
# Out:
# ✅ Environment Ready. TensorFlow version: 2.20.0
# ✅ Keras version: 2.20.1

# %%
FinalPath = Path(THYROID_PATH, 'FinalData.npy')
npz_content = np.load(FinalPath, allow_pickle=True)

# Extract and handle NaNs
X_train = np.nan_to_num(npz_content['X_cancer_train'])
y_train = npz_content['y_cancer_train']

print(f"✅ Data Loaded. X shape: {X_train.shape}, y shape: {y_train.shape}")

# Create output directories
os.makedirs("fit_history", exist_ok=True)
output_folder = Path(RESULTS_PATH, 'Final_1DCNN_Results')
output_folder.mkdir(exist_ok=True)
# Out:
# ✅ Data Loaded. X shape: (412, 485577), y shape: (412,)

# %%
# --- 1. Define the missing helper function first ---
def get_uncompiled_model(reset_last_layer=False):
    # Construct the path to your saved model folder
    load_path = os.path.join(MODEL_PATH, 'pan-cancer-leaky-relu')
    print(f"Loading base model from: {load_path}")
    
    # Load the model (works with folder format because of tf_keras)
    model = keras.models.load_model(load_path)
    
    # (Optional) Logic to reset layer if needed, based on your previous code
    if reset_last_layer:
        x = model.layers[-2].output
        output = keras.layers.Dense(1, activation='sigmoid', name='output_follicolar')(x)
        model = keras.Model(inputs=model.input, outputs=output)
        
    return model

# --- 2. Define the Subtype Model Builder ---
num_classes = len(np.unique(y_train)) 
print(f"Number of classes detected: {num_classes}")

def get_subtype_model(num_classes):
    # Load the base model without resetting the last layer
    model = get_uncompiled_model(reset_last_layer=False) 
    
    # Extract the features before the old head (second to last layer)
    x = model.layers[-2].output 
    
    # Add new head for multiclass subtypes
    output = keras.layers.Dense(num_classes, activation='softmax', name='subtype_output')(x)
    return keras.Model(inputs=model.input, outputs=output)

# --- 3. Instantiate and Compile ---
model = get_subtype_model(num_classes)

model.compile(
    loss='sparse_categorical_crossentropy', 
    optimizer=keras.optimizers.Adam(learning_rate=3e-5),
    metrics=['accuracy']
)

print("✅ Model compiled successfully.")
model.summary()
# Out:
# Number of classes detected: 2
# Loading base model from: /home/Capstone_Team78/Dataset/Models/pan-cancer-leaky-relu
# 2026-02-14 10:45:37.283768: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ✅ Model compiled successfully.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 485577, 1)]          0         []
#
#  conv1d_12 (Conv1D)          (None, 485577, 16)           96        ['input_2[0][0]']
#
#  batch_normalization_12 (Ba  (None, 485577, 16)           64        ['conv1d_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 485577, 16)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  spatial_dropout1d_12 (Spat  (None, 485577, 16)           0         ['leaky_re_lu_12[0][0]']
#  ialDropout1D)
#
#  conv1d_13 (Conv1D)          (None, 485577, 16)           1296      ['spatial_dropout1d_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 485577, 16)           64        ['conv1d_13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 485577, 16)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  spatial_dropout1d_13 (Spat  (None, 485577, 16)           0         ['leaky_re_lu_13[0][0]']
#  ialDropout1D)
#
#  conv1d_14 (Conv1D)          (None, 485577, 16)           1296      ['spatial_dropout1d_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 485577, 16)           64        ['conv1d_14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 485577, 16)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  spatial_dropout1d_14 (Spat  (None, 485577, 16)           0         ['leaky_re_lu_14[0][0]']
#  ialDropout1D)
#
#  conv1d_15 (Conv1D)          (None, 485577, 16)           1296      ['spatial_dropout1d_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 485577, 16)           64        ['conv1d_15[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 485577, 16)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  spatial_dropout1d_15 (Spat  (None, 485577, 16)           0         ['leaky_re_lu_15[0][0]']
#  ialDropout1D)
#
#  add_3 (Add)                 (None, 485577, 16)           0         ['spatial_dropout1d_15[0][0]',
#                                                                      'spatial_dropout1d_12[0][0]']
#
#  avgpool1 (AveragePooling1D  (None, 242788, 16)           0         ['add_3[0][0]']
#  )
#
#  conv1d_16 (Conv1D)          (None, 242788, 32)           2592      ['avgpool1[0][0]']
#
#  batch_normalization_16 (Ba  (None, 242788, 32)           128       ['conv1d_16[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 242788, 32)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  spatial_dropout1d_16 (Spat  (None, 242788, 32)           0         ['leaky_re_lu_16[0][0]']
#  ialDropout1D)
#
#  conv1d_17 (Conv1D)          (None, 242788, 32)           5152      ['spatial_dropout1d_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 242788, 32)           128       ['conv1d_17[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 242788, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  spatial_dropout1d_17 (Spat  (None, 242788, 32)           0         ['leaky_re_lu_17[0][0]']
#  ialDropout1D)
#
#  conv1d_18 (Conv1D)          (None, 242788, 32)           5152      ['spatial_dropout1d_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 242788, 32)           128       ['conv1d_18[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 242788, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  spatial_dropout1d_18 (Spat  (None, 242788, 32)           0         ['leaky_re_lu_18[0][0]']
#  ialDropout1D)
#
#  conv1d_19 (Conv1D)          (None, 242788, 32)           5152      ['spatial_dropout1d_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 242788, 32)           128       ['conv1d_19[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 242788, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  spatial_dropout1d_19 (Spat  (None, 242788, 32)           0         ['leaky_re_lu_19[0][0]']
#  ialDropout1D)
#
#  add_4 (Add)                 (None, 242788, 32)           0         ['spatial_dropout1d_19[0][0]',
#                                                                      'spatial_dropout1d_16[0][0]']
#
#  average_pooling1d_2 (Avera  (None, 121394, 32)           0         ['add_4[0][0]']
#  gePooling1D)
#
#  avgpool2 (AveragePooling1D  (None, 60697, 32)            0         ['average_pooling1d_2[0][0]']
#  )
#
#  conv1d_20 (Conv1D)          (None, 60697, 64)            10304     ['avgpool2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 60697, 64)            256       ['conv1d_20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 60697, 64)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  spatial_dropout1d_20 (Spat  (None, 60697, 64)            0         ['leaky_re_lu_20[0][0]']
#  ialDropout1D)
#
#  conv1d_21 (Conv1D)          (None, 60697, 64)            20544     ['spatial_dropout1d_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 60697, 64)            256       ['conv1d_21[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 60697, 64)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  spatial_dropout1d_21 (Spat  (None, 60697, 64)            0         ['leaky_re_lu_21[0][0]']
#  ialDropout1D)
#
#  conv1d_22 (Conv1D)          (None, 60697, 64)            20544     ['spatial_dropout1d_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 60697, 64)            256       ['conv1d_22[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 60697, 64)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  spatial_dropout1d_22 (Spat  (None, 60697, 64)            0         ['leaky_re_lu_22[0][0]']
#  ialDropout1D)
#
#  conv1d_23 (Conv1D)          (None, 60697, 64)            20544     ['spatial_dropout1d_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 60697, 64)            256       ['conv1d_23[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 60697, 64)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  spatial_dropout1d_23 (Spat  (None, 60697, 64)            0         ['leaky_re_lu_23[0][0]']
#  ialDropout1D)
#
#  add_5 (Add)                 (None, 60697, 64)            0         ['spatial_dropout1d_23[0][0]',
#                                                                      'spatial_dropout1d_20[0][0]']
#
#  average_pooling1d_3 (Avera  (None, 30348, 64)            0         ['add_5[0][0]']
#  gePooling1D)
#
#  flatten_1 (Flatten)         (None, 1942272)              0         ['average_pooling1d_3[0][0]']
#
#  subtype_output (Dense)      (None, 2)                    3884546   ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 3980306 (15.18 MB)
# Trainable params: 3979410 (15.18 MB)
# Non-trainable params: 896 (3.50 KB)
# __________________________________________________________________________________________________

# %%
#Retrain Base Model for thyroid cancer classification
# Run this in a new cell or terminal if needed
# !rm -rf ckpt-thyroid-cancer

# %%
from tensorflow.keras.callbacks import EarlyStopping

# 1. Load Subtype Data (Ensure keys match your .npz file)
# Note: If your .npz only has 'X_cancer_train', change this line!
if 'X_subtype_train' in npz_content:
    X_train_sub = np.nan_to_num(npz_content['X_subtype_train']).astype('float32')
    y_train_sub = npz_content['y_subtype_train']
else:
    print("⚠️ 'X_subtype_train' not found. Using 'X_cancer_train' from Cell 2.")
    X_train_sub = X_train # defined in Cell 2
    y_train_sub = y_train # defined in Cell 2

# 2. Check how many subtypes we are dealing with
num_classes = len(np.unique(y_train_sub))
print(f"🎯 Training for {num_classes} subtypes.")

# 3. Initialize model (Using the function we defined in Cell 3)
# We don't need 'make_or_restore_model' because we already built 'model' in Cell 3.
# If you want to start fresh, uncomment the next line:
# model = get_subtype_model(num_classes) 

# Define the callback since it wasn't defined in this cell block
early_stopping_cb = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True,
    verbose=1
)

# 4. Train
print("🚀 Starting training...")
subtype_history = model.fit(
    X_train_sub, 
    y_train_sub, 
    batch_size=4, # Low batch size is good for memory
    epochs=30, 
    callbacks=[early_stopping_cb], 
    validation_split=0.2, 
    shuffle=True
)

# 5. Save Results
os.makedirs('fit_history', exist_ok=True)
subtype_df = pd.DataFrame(subtype_history.history)
subtype_df.to_csv(os.path.join('fit_history','thyroid-subtype.csv'))

# 6. Save Model
# FIXED: Use .h5 because we are in Legacy Keras mode
save_path = os.path.join(MODEL_PATH, "thyroid-subtype.h5")
model.save(save_path)

print(f"✅ Subtype Model Training Complete. Model saved to: {save_path}")
# Out:
# 🎯 Training for 2 subtypes.
# 🚀 Starting training...
# Epoch 1/30
# 74/74 [==============================] - 241s 3s/step - loss: 1.0777 - accuracy: 0.7143 - val_loss: 1.2554 - val_accuracy: 0.2838
# Epoch 2/30
# 74/74 [==============================] - 240s 3s/step - loss: 0.9524 - accuracy: 0.7381 - val_loss: 0.4603 - val_accuracy: 0.8378
# Epoch 3/30
# 74/74 [==============================] - 241s 3s/step - loss: 0.6429 - accuracy: 0.8061 - val_loss: 1.1143 - val_accuracy: 0.7703
# Epoch 4/30
# 74/74 [==============================] - 242s 3s/step - loss: 0.4861 - accuracy: 0.8469 - val_loss: 0.5526 - val_accuracy: 0.7703
# Epoch 5/30
# 74/74 [==============================] - 241s 3s/step - loss: 0.4067 - accuracy: 0.8673 - val_loss: 0.5860 - val_accuracy: 0.7703
# Epoch 6/30
# 74/74 [==============================] - 241s 3s/step - loss: 0.4596 - accuracy: 0.8401 - val_loss: 0.5599 - val_accuracy: 0.7838
# Epoch 7/30
# 74/74 [==============================] - 241s 3s/step - loss: 0.3281 - accuracy: 0.8571 - val_loss: 0.5266 - val_accuracy: 0.8108
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# ✅ Subtype Model Training Complete. Model saved to: /home/Capstone_Team78/Dataset/Models/thyroid-subtype.h5
# /home/Capstone_Team78/venv/lib/python3.12/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd
import os

# 1. Use the correct variable name (npz_content)
# Note: Ensure npz_content is loaded. If not, reload it like in Cell 2.
if 'X_subtype_train' in npz_content:
    X_train_sub = np.nan_to_num(npz_content['X_subtype_train']).astype('float32')
    y_train_sub = npz_content['y_subtype_train']
else:
    # Fallback if your npz only has the main train set
    print("⚠️ Using X_cancer_train as fallback.")
    X_train_sub = X_train 
    y_train_sub = y_train

# 2. Check classes
num_subtypes = len(np.unique(y_train_sub))
print(f"🧬 Detected {num_subtypes} thyroid subtypes. Initializing training...")

# 3. Initialize the model using YOUR function from Cell 3
# We use get_subtype_model, not make_or_restore_model
model_subtype = get_subtype_model(num_subtypes)

# Re-compile just to be safe (ensures fresh optimizer state)
model_subtype.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=3e-5),
    metrics=['accuracy']
)

# Define callback (in case it wasn't defined in previous cells)
early_stopping_cb = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    restore_best_weights=True, 
    verbose=1
)

# 4. Train
print("🚀 Starting Subtype Training...")
subtype_history = model_subtype.fit(
    X_train_sub,
    y_train_sub, 
    batch_size=4, 
    epochs=30, 
    callbacks=[early_stopping_cb], 
    validation_split=0.2, 
    shuffle=True
)

# 5. Save history and the model
os.makedirs('fit_history', exist_ok=True)
subtype_df = pd.DataFrame(subtype_history.history)
subtype_df.to_csv(os.path.join('fit_history', 'thyroid-subtype.csv'))

# FIXED: Save as .h5 because we are in Legacy Keras mode
save_path = os.path.join(MODEL_PATH, "thyroid-subtype.h5")
model_subtype.save(save_path)

print(f"✅ Subtype Detection Model saved successfully to: {save_path}")
# Out:
# 🧬 Detected 2 thyroid subtypes. Initializing training...
# Loading base model from: /home/Capstone_Team78/Dataset/Models/pan-cancer-leaky-relu
# 🚀 Starting Subtype Training...
# Epoch 1/30
# 74/74 [==============================] - 243s 3s/step - loss: 1.0059 - accuracy: 0.7007 - val_loss: 0.4313 - val_accuracy: 0.7838
# Epoch 2/30
# 74/74 [==============================] - 244s 3s/step - loss: 0.5501 - accuracy: 0.7483 - val_loss: 0.7219 - val_accuracy: 0.7703
# Epoch 3/30
# 74/74 [==============================] - 243s 3s/step - loss: 1.0683 - accuracy: 0.7279 - val_loss: 1.5828 - val_accuracy: 0.7703
# Epoch 4/30
# 74/74 [==============================] - 243s 3s/step - loss: 0.7146 - accuracy: 0.7959 - val_loss: 0.5167 - val_accuracy: 0.8243
# Epoch 5/30
# 74/74 [==============================] - 242s 3s/step - loss: 0.4789 - accuracy: 0.8367 - val_loss: 0.6599 - val_accuracy: 0.7838
# Epoch 6/30
# 74/74 [==============================] - 244s 3s/step - loss: 0.4174 - accuracy: 0.8401 - val_loss: 0.8473 - val_accuracy: 0.7568
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Subtype Detection Model saved successfully to: /home/Capstone_Team78/Dataset/Models/thyroid-subtype.h5
# /home/Capstone_Team78/venv/lib/python3.12/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.2,shuffle=True, stratify=y)
#
# from collections import Counter
# X_train_fill = SimpleImputer(strategy='constant').fit_transform(X_train,y_train)
# X_train_over,y_train_over = over.fit_resample(X_train_fill,y_train)
# X_train_under,y_train_under = under.fit_resample(X_train_over,y_train_over)
#
# X_test_fill = SimpleImputer(strategy='constant').fit_transform(X_test,y_test)
# X_test_over,y_test_over = over.fit_resample(X_test_fill,y_test)
# X_test_under,y_test_under = under.fit_resample(X_test_over,y_test_over)
#
# print(Counter(y_train))
# print(Counter(y_train_under))
#
# print(Counter(y_test))
# print(Counter(y_test_under))

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Generate Predictions
print("🔍 Generating predictions for evaluation...")
# We use the trained 'model_subtype' from Cell 6
y_pred_probs = model_subtype.predict(X_train_sub) 
y_pred = np.argmax(y_pred_probs, axis=1)

# 2. Confusion Matrix
cm = confusion_matrix(y_train_sub, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix: DNA Methylation Subtypes')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# 3. Classification Report
print("\n📝 Classification Report:\n")
print(classification_report(y_train_sub, y_pred))
# Out:
# 🔍 Generating predictions for evaluation...
# 12/12 [==============================] - 33s 3s/step
# 📝 Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.99      0.89       287
#          1.0       0.75      0.15      0.25        81
#
#     accuracy                           0.80       368
#    macro avg       0.78      0.57      0.57       368
# weighted avg       0.79      0.80      0.75       368

# %%
from sklearn.utils import class_weight
import numpy as np

# 1. Calculate Class Weights
# This automatically assigns higher weight to the minority class (1)
class_weights_vals = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_sub),
    y=y_train_sub
)

# Convert to dictionary format required by Keras
class_weights_dict = dict(enumerate(class_weights_vals))

print(f"⚖️ Computed Class Weights: {class_weights_dict}")
# Example output might look like: {0: 0.64, 1: 2.27}
# This means the model gets ~3.5x more penalty for missing a Class 1 sample.

# 2. Re-Initialize Model (Start Fresh)
# We must reset the model so it doesn't remember the "lazy" strategy
model_subtype_weighted = get_subtype_model(num_subtypes)

model_subtype_weighted.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=3e-5),
    metrics=['accuracy']
)

# 3. Train with Class Weights
print("🚀 Retraining with Class Weights...")
weighted_history = model_subtype_weighted.fit(
    X_train_sub,
    y_train_sub,
    batch_size=4,
    epochs=30,
    callbacks=[early_stopping_cb],
    validation_split=0.2,
    shuffle=True,
    class_weight=class_weights_dict  # <--- KEY ADDITION
)

# 4. Save the Weighted Model
save_path_weighted = os.path.join(MODEL_PATH, "thyroid-subtype-weighted.h5")
model_subtype_weighted.save(save_path_weighted)
print(f"✅ Weighted Model Saved to: {save_path_weighted}")
# Out:
# ⚖️ Computed Class Weights: {0: np.float64(0.6411149825783972), 1: np.float64(2.271604938271605)}
# Loading base model from: /home/Capstone_Team78/Dataset/Models/pan-cancer-leaky-relu
# 🚀 Retraining with Class Weights...
# Epoch 1/30
# 74/74 [==============================] - 242s 3s/step - loss: 1.0930 - accuracy: 0.5884 - val_loss: 0.4004 - val_accuracy: 0.8243
# Epoch 2/30
# 74/74 [==============================] - 242s 3s/step - loss: 0.9525 - accuracy: 0.6701 - val_loss: 0.4169 - val_accuracy: 0.8378
# Epoch 3/30
# 74/74 [==============================] - 243s 3s/step - loss: 1.1119 - accuracy: 0.6531 - val_loss: 0.5786 - val_accuracy: 0.7703
# Epoch 4/30
# 74/74 [==============================] - 243s 3s/step - loss: 0.8315 - accuracy: 0.7449 - val_loss: 0.5962 - val_accuracy: 0.7568
# Epoch 5/30
# 74/74 [==============================] - 244s 3s/step - loss: 1.1288 - accuracy: 0.7075 - val_loss: 0.5994 - val_accuracy: 0.7838
# Epoch 6/30
# 74/74 [==============================] - 244s 3s/step - loss: 0.7632 - accuracy: 0.7857 - val_loss: 0.5974 - val_accuracy: 0.7838
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# ✅ Weighted Model Saved to: /home/Capstone_Team78/Dataset/Models/thyroid-subtype-weighted.h5
# /home/Capstone_Team78/venv/lib/python3.12/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# --- 1. Compute Class Weights ---
class_weights_vals = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_sub),
    y=y_train_sub
)
class_weights_dict = dict(enumerate(class_weights_vals))
print(f"⚖️ Class Weights Active: {class_weights_dict}")

# --- 2. Force-Reset the Model ---
# We use a new name 'final_model' to avoid conflicts
final_model = get_subtype_model(num_subtypes)

final_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=3e-5), 
    metrics=['accuracy']
)

# --- 3. Train with Weights ---
print("🚀 Retraining with Class Weights...")
history = final_model.fit(
    X_train_sub,
    y_train_sub,
    batch_size=4,
    epochs=30,
    validation_split=0.2,
    callbacks=[early_stopping_cb],
    class_weight=class_weights_dict, # Applying weights here
    verbose=1
)

# --- 4. IMMEDIATE EVALUATION ---
print("\n🔍 Generating new predictions...")
y_pred_probs = final_model.predict(X_train_sub) 
y_pred_new = np.argmax(y_pred_probs, axis=1)

# Plot
cm = confusion_matrix(y_train_sub, y_pred_new)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Weighted Model Results')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Report
print(classification_report(y_train_sub, y_pred_new))
# Out:
# ⚖️ Class Weights Active: {0: np.float64(0.6411149825783972), 1: np.float64(2.271604938271605)}
# Loading base model from: /home/Capstone_Team78/Dataset/Models/pan-cancer-leaky-relu
# 🚀 Retraining with Class Weights...
# Epoch 1/30
# 74/74 [==============================] - 240s 3s/step - loss: 1.3073 - accuracy: 0.5816 - val_loss: 0.6109 - val_accuracy: 0.7432
# Epoch 2/30
# 74/74 [==============================] - 244s 3s/step - loss: 1.0134 - accuracy: 0.6259 - val_loss: 0.9312 - val_accuracy: 0.6081
# Epoch 3/30
# 74/74 [==============================] - 245s 3s/step - loss: 1.0350 - accuracy: 0.6905 - val_loss: 0.5599 - val_accuracy: 0.7703
# Epoch 4/30
# 74/74 [==============================] - 247s 3s/step - loss: 1.0341 - accuracy: 0.7143 - val_loss: 0.9216 - val_accuracy: 0.7838
# Epoch 5/30
# 74/74 [==============================] - 243s 3s/step - loss: 0.8388 - accuracy: 0.7415 - val_loss: 1.6945 - val_accuracy: 0.4459
# Epoch 6/30
# 74/74 [==============================] - 250s 3s/step - loss: 0.7355 - accuracy: 0.7483 - val_loss: 0.8562 - val_accuracy: 0.7297
# Epoch 7/30
# 74/74 [==============================] - 253s 3s/step - loss: 0.8226 - accuracy: 0.7789 - val_loss: 1.3022 - val_accuracy: 0.6486
# Epoch 8/30
# 74/74 [==============================] - 253s 3s/step - loss: 0.8409 - accuracy: 0.7313 - val_loss: 0.7703 - val_accuracy: 0.7838
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# 🔍 Generating new predictions...
# 12/12 [==============================] - 36s 3s/step
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.86      0.90       287
#          1.0       0.63      0.84      0.72        81
#
#     accuracy                           0.86       368
#    macro avg       0.79      0.85      0.81       368
# weighted avg       0.88      0.86      0.86       368

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import os

# --- 1. Define the Optimized Model Architecture ---
def get_optimized_subtype_model(num_classes):
    # Load base model (using your existing function)
    base_model = get_uncompiled_model(reset_last_layer=False)
    
    # Extract features from the second-to-last layer
    x = base_model.layers[-2].output 
    
    # --- Optimization: Regularization & Dropout ---
    # Dropout 50%: Randomly disables half the neurons to prevent memorization
    x = keras.layers.Dropout(0.5)(x) 
    
    # L2 Regularization: Punishes large weights to keep the model simple
    x = keras.layers.Dense(
        64, 
        activation='relu', 
        kernel_regularizer=regularizers.l2(0.01) 
    )(x)
    
    # Dropout 30%: A second safety layer
    x = keras.layers.Dropout(0.3)(x)
    
    # Final Output Head
    output = keras.layers.Dense(
        num_classes, 
        activation='softmax', 
        name='subtype_output'
    )(x)
    
    return keras.Model(inputs=base_model.input, outputs=output)

print("✅ Optimized Model Architecture defined.")

# --- 2. Setup & Compile ---
# Calculate Class Weights (Critical for your imbalance)
class_weights_vals = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_sub),
    y=y_train_sub
)
class_weights_dict = dict(enumerate(class_weights_vals))
print(f"⚖️ Class Weights: {class_weights_dict}")

# Initialize the new model
final_model_v2 = get_optimized_subtype_model(num_subtypes)

final_model_v2.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=2e-5), # Lower LR for stability
    metrics=['accuracy']
)

# Define Early Stopping
early_stopping_cb = EarlyStopping(
    monitor='val_loss', 
    patience=8, # Increased patience slightly for the slower learning rate
    restore_best_weights=True,
    verbose=1
)

# --- 3. Train ---
print("🚀 Training Optimized Model (High Regularization)...")
history_v2 = final_model_v2.fit(
    X_train_sub,
    y_train_sub,
    batch_size=8, 
    epochs=40,    
    validation_split=0.2,
    callbacks=[early_stopping_cb],
    class_weight=class_weights_dict, 
    verbose=1
)

# --- 4. Evaluate Immediately ---
print("\n🔍 Evaluating Optimized Model...")
y_pred_probs = final_model_v2.predict(X_train_sub) 
y_pred_v2 = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_train_sub, y_pred_v2)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False) 
plt.title('Optimized Model Results')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification Report
print(classification_report(y_train_sub, y_pred_v2))

# --- 5. Save the Best Model ---
save_path_v2 = os.path.join(MODEL_PATH, "thyroid-subtype-optimized.h5")
final_model_v2.save(save_path_v2)
print(f"✅ Optimized Model Saved to: {save_path_v2}")
# Out:
# ✅ Optimized Model Architecture defined.
# ⚖️ Class Weights: {0: np.float64(0.6411149825783972), 1: np.float64(2.271604938271605)}
# Loading base model from: /home/Capstone_Team78/Dataset/Models/pan-cancer-leaky-relu
# 🚀 Training Optimized Model (High Regularization)...
# Epoch 1/40
# 37/37 [==============================] - 262s 7s/step - loss: 2.0446 - accuracy: 0.5884 - val_loss: 1.7221 - val_accuracy: 0.4730
# Epoch 2/40
# 37/37 [==============================] - 258s 7s/step - loss: 1.6643 - accuracy: 0.6259 - val_loss: 1.5634 - val_accuracy: 0.5000
# Epoch 3/40
# 37/37 [==============================] - 263s 7s/step - loss: 1.4594 - accuracy: 0.6803 - val_loss: 1.3497 - val_accuracy: 0.7838
# Epoch 4/40
# 37/37 [==============================] - 267s 7s/step - loss: 1.3453 - accuracy: 0.6939 - val_loss: 1.5057 - val_accuracy: 0.3649
# Epoch 5/40
# 37/37 [==============================] - 266s 7s/step - loss: 1.2686 - accuracy: 0.6429 - val_loss: 1.1209 - val_accuracy: 0.7973
# Epoch 6/40
# 37/37 [==============================] - 265s 7s/step - loss: 1.2216 - accuracy: 0.6293 - val_loss: 1.1624 - val_accuracy: 0.7973
# Epoch 7/40
# 37/37 [==============================] - 266s 7s/step - loss: 1.1236 - accuracy: 0.6803 - val_loss: 1.0868 - val_accuracy: 0.7838
# Epoch 8/40
# 37/37 [==============================] - 264s 7s/step - loss: 1.0935 - accuracy: 0.6871 - val_loss: 1.0964 - val_accuracy: 0.7703
# Epoch 9/40
# 37/37 [==============================] - 266s 7s/step - loss: 1.0495 - accuracy: 0.7279 - val_loss: 0.9933 - val_accuracy: 0.8108
# Epoch 10/40
# 37/37 [==============================] - 265s 7s/step - loss: 0.9915 - accuracy: 0.7619 - val_loss: 1.0980 - val_accuracy: 0.7162
# Epoch 11/40
# 37/37 [==============================] - 265s 7s/step - loss: 0.9855 - accuracy: 0.7109 - val_loss: 0.8553 - val_accuracy: 0.8243
# Epoch 12/40
# 37/37 [==============================] - 260s 7s/step - loss: 0.9161 - accuracy: 0.8095 - val_loss: 0.9458 - val_accuracy: 0.7703
# Epoch 13/40
# 37/37 [==============================] - 265s 7s/step - loss: 0.8546 - accuracy: 0.8061 - val_loss: 0.9220 - val_accuracy: 0.7703
# Epoch 14/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.8436 - accuracy: 0.7823 - val_loss: 0.8467 - val_accuracy: 0.7838
# Epoch 15/40
# 37/37 [==============================] - 252s 7s/step - loss: 0.7895 - accuracy: 0.7993 - val_loss: 0.8065 - val_accuracy: 0.7838
# Epoch 16/40
# 37/37 [==============================] - 254s 7s/step - loss: 0.7764 - accuracy: 0.8027 - val_loss: 0.8011 - val_accuracy: 0.7838
# Epoch 17/40
# 37/37 [==============================] - 254s 7s/step - loss: 0.8238 - accuracy: 0.7619 - val_loss: 0.8178 - val_accuracy: 0.7838
# Epoch 18/40
# 37/37 [==============================] - 254s 7s/step - loss: 0.7746 - accuracy: 0.8027 - val_loss: 0.9287 - val_accuracy: 0.7297
# Epoch 19/40
# 37/37 [==============================] - 254s 7s/step - loss: 0.7684 - accuracy: 0.7687 - val_loss: 0.8506 - val_accuracy: 0.7568
# Epoch 20/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.7176 - accuracy: 0.8197 - val_loss: 0.9013 - val_accuracy: 0.7297
# Epoch 21/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.7058 - accuracy: 0.7959 - val_loss: 0.7882 - val_accuracy: 0.7838
# Epoch 22/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.6829 - accuracy: 0.8061 - val_loss: 0.7476 - val_accuracy: 0.7838
# Epoch 23/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.6656 - accuracy: 0.8333 - val_loss: 0.6951 - val_accuracy: 0.8108
# Epoch 24/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.6632 - accuracy: 0.8061 - val_loss: 0.6912 - val_accuracy: 0.8108
# Epoch 25/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.6226 - accuracy: 0.8435 - val_loss: 0.7117 - val_accuracy: 0.7838
# Epoch 26/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.6097 - accuracy: 0.8401 - val_loss: 0.7900 - val_accuracy: 0.7568
# Epoch 27/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.5915 - accuracy: 0.8129 - val_loss: 0.7141 - val_accuracy: 0.7838
# Epoch 28/40
# 37/37 [==============================] - 257s 7s/step - loss: 0.5709 - accuracy: 0.8367 - val_loss: 0.7353 - val_accuracy: 0.7703
# Epoch 29/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.5407 - accuracy: 0.8571 - val_loss: 0.6742 - val_accuracy: 0.8108
# Epoch 30/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.5609 - accuracy: 0.8503 - val_loss: 0.6669 - val_accuracy: 0.7973
# Epoch 31/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.5392 - accuracy: 0.8707 - val_loss: 0.7085 - val_accuracy: 0.7568
# Epoch 32/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.4997 - accuracy: 0.8741 - val_loss: 0.7058 - val_accuracy: 0.7568
# Epoch 33/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.4871 - accuracy: 0.8980 - val_loss: 0.6542 - val_accuracy: 0.7973
# Epoch 34/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.5138 - accuracy: 0.8571 - val_loss: 0.6470 - val_accuracy: 0.7838
# Epoch 35/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.4612 - accuracy: 0.8980 - val_loss: 0.6633 - val_accuracy: 0.7838
# Epoch 36/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.4595 - accuracy: 0.8946 - val_loss: 0.6687 - val_accuracy: 0.7838
# Epoch 37/40
# 37/37 [==============================] - 255s 7s/step - loss: 0.4312 - accuracy: 0.8810 - val_loss: 0.6504 - val_accuracy: 0.7838
# Epoch 38/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.4275 - accuracy: 0.9082 - val_loss: 0.7912 - val_accuracy: 0.7703
# Epoch 39/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.4437 - accuracy: 0.8980 - val_loss: 0.6430 - val_accuracy: 0.7838
# Epoch 40/40
# 37/37 [==============================] - 256s 7s/step - loss: 0.4449 - accuracy: 0.9014 - val_loss: 0.6539 - val_accuracy: 0.7838
# Restoring model weights from the end of the best epoch: 39.
#
# 🔍 Evaluating Optimized Model...
# 12/12 [==============================] - 36s 3s/step
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.95       287
#          1.0       0.76      0.91      0.83        81
#
#     accuracy                           0.92       368
#    macro avg       0.87      0.92      0.89       368
# weighted avg       0.93      0.92      0.92       368
# /home/Capstone_Team78/venv/lib/python3.12/site-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ✅ Optimized Model Saved to: /home/Capstone_Team78/Dataset/Models/thyroid-subtype-optimized.h5

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.50.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=2 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (2.4.2)
# Requirement already satisfied: scipy in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (1.17.0)
# Requirement already satisfied: scikit-learn in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (1.8.0)
# Requirement already satisfied: pandas in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (3.0.0)
# Collecting tqdm>=4.27.0 (from shap)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>20.9 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (26.0)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap)
#   Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from shap) (4.15.0)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.54->shap)
#   Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Collecting numpy>=2 (from shap)
#   Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.3.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/Capstone_Team78/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Downloading shap-0.50.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading numba-0.63.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 11.5 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.0 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading llvmlite-0.46.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: tqdm, slicer, numpy, llvmlite, cloudpickle, numba, shap
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.2
#     Uninstalling numpy-2.4.2:
#       Successfully uninstalled numpy-2.4.2
# Successfully installed cloudpickle-3.1.2 llvmlite-0.46.0 numba-0.63.1 numpy-2.3.5 shap-0.50.0 slicer-0.0.8 tqdm-4.67.3

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# --- 1. Prepare Feature Names ---
# NOTE: Ensure 'cpg_names' contains the list of CpG site IDs (e.g., cg00000029) 
# from your original dataset columns.
# If you don't have them handy, the plot will use 'Feature 0, 1, 2...'
try:
    # Example: cpg_names = original_df.columns.tolist()
    # Check if cpg_names is already defined
    feature_list = cpg_names 
except NameError:
    print("⚠️ 'cpg_names' not found. Using numeric indices.")
    feature_list = [f"Feature {i}" for i in range(X_train_sub.shape[1])]

# --- 2. Create the Background Baseline ---
# Using 200 samples provides a stable 'average' methylation state.
# 128GB RAM allows for this larger background without kernel crashes.
background_indices = np.random.choice(X_train_sub.shape[0], 200, replace=False)
background_data = X_train_sub[background_indices]

# --- 3. Initialize DeepExplainer ---
print("⏳ Initializing SHAP DeepExplainer (using optimized background)...")
explainer = shap.DeepExplainer(final_model_v2, background_data)

# --- 4. Calculate SHAP Values ---
# Explaining 50 test samples gives a broad look at model behavior.
# This process may take 5-10 minutes due to the 485,577 features.
print(f"🔍 Calculating SHAP values for 50 samples across {X_train_sub.shape[1]} features...")
shap_values = explainer.shap_values(X_train_sub[:50])

# --- 5. Visualization: Beeswarm Plot ---
# We focus on Subtype 1 (the minority class) where you achieved 91% recall.
plt.figure(figsize=(14, 10))
shap.summary_plot(
    shap_values[1], 
    X_train_sub[:50], 
    feature_names=feature_list, 
    max_display=30, # Shows the top 30 biological markers
    plot_type="dot",
    show=False
)
plt.title("Top 30 DNA Methylation Markers for Thyroid Subtype Detection", fontsize=16)
plt.show()

# --- 6. Function to Extract Top 10 Feature Names ---
def get_top_biomarkers(shap_vals, features, top_n=10):
    vals = np.abs(shap_vals).mean(0)
    feature_importance = pd.DataFrame(list(zip(features, vals)), columns=['col_name','feature_importance_vals'])
    feature_importance.sort_values(by=['feature_importance_vals'], ascending=False, inplace=True)
    return feature_importance.head(top_n)

top_10 = get_top_biomarkers(shap_values[1], feature_list)
print("\n🧬 Top 10 Biological Markers Identified by SHAP:")
print(top_10)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import shap
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/shap/__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/shap/_explanation.py:17
#      14 import sklearn
#      15 from slicer import Alias, Obj, Slicer
# ---> 17 from .utils._clustering import hclust_ordering
#      18 from .utils._exceptions import DimensionError
#      19 from .utils._general import OpChain
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/shap/utils/__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)     20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/shap/utils/_clustering.py:12
#      10 import scipy.spatial
#      11 import sklearn
# ---> 12 from numba import njit
#      14 from ..utils._exceptions import DimensionError
#      15 from ._show_progress import show_progress
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File /home/Capstone_Team78/venv/lib/python3.12/site-packages/numba/__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 3):
#      43     msg = (f"Numba needs NumPy 2.3 or less. Got NumPy "
#      44             f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.3 or less. Got NumPy 2.4.
